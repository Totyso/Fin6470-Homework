# %% [markdown]
# __Rolling Regression__

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
plt.plot(y, linewidth=3);

# %%
#interpret x and y as log prices

# %%
dS = np.diff(y)
dF = np.diff(x)

# %%
dS[:10]
# Out:
# array([ -7.47803044,  -6.13027331, -11.22270579,  -8.63959205,
#        -11.94578599,  -7.1926685 ,  -4.62512595,  19.76166022,
#        -12.74105967,   5.02045623])

# %%
dF[:10]
# Out:
# array([-0.70893292, -1.57150584, -1.38170348, -0.90788245, -1.69226126,
#        -0.94752601, -0.63575001,  2.34817672, -1.98236966,  1.39214769])

# %%
dS.shape
# Out:
# (499,)

# %%
dF.shape
# Out:
# (499,)

# %%
M = 60
L = N - M

# %%
h = np.empty(L)

# %%
ibeg = 0
iend = M

for i in range(L):
    reg = linregress(dF[ibeg:iend], dS[ibeg:iend])
    h[i] = reg.slope
    ibeg += 1
    iend += 1

# %%
ts = pd.Series(h)

# %%
ts.plot(grid=True, color="orange");
